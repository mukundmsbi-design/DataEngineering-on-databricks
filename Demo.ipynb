# %%
df = spark.read.table("course_ws.default.olist_customers_dataset")
display(df)

dbutils.fs.ls('/Volumes/course_ws/default/olist')

dbutils.fs.ls('/Volumes/course_ws/default/olist')
#read volume /Volumes/course_ws/default/olist

dbutils.fs.ls('/Volumes/course_ws/defaultolist')
